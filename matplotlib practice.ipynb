# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
fig = plt.figure()

# %%
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
#axes.plot(x,y,'r')
#for current_ax in axes:
   # current_ax.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title('First')
axes[1].plot(y,x)
axes[1].set_title('Second')
plt.tight_layout()

# %% [markdown]
# # FIGURE SIZE AND DPI

# %%
fig1 = plt.figure(figsize=(3,2),dpi=1000)
ax = fig1.add_axes([0,0,1,1])
ax.set_title('Title')
ax.set_ylabel('Y Label')
ax.set_xlabel('X Label')
ax.plot(x,y,label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f8782a8119fa> in <module>
#       4 ax.set_ylabel('Y Label')
#       5 ax.set_xlabel('X Label')
# ----> 6 ax.plot(x,y,label)
#
# NameError: name 'label' is not defined

# %%
fig1,axes1 = plt.subplots(nrows=2,ncols=1,figsize=(8,2),dpi=1000)

axes1[0].plot(x,y)

axes1[1].plot(y,x)

plt.tight_layout()

# %%
fig1.savefig('my_figure1.png')

# %% [markdown]
# # PLOT APPEARANCE

# %%
fig2 = plt.figure()
ax1 = fig2.add_axes([0,0,1,1])
ax1.set_xlim([0,1])
ax1.set_ylim([0,2])
ax1.plot(x,y,color='indigo',lw=20,alpha=0.7,ls=':',marker='o',markersize=25,
        markerfacecolor='yellow',markeredgewidth=3,markeredgecolor='green')

# %%
len(x)
# Out:
# 11
